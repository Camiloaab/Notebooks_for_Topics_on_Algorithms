# %% [markdown]
# ## RSA Protocol

# %%
import math
import numpy as np

# %%
def Euclides(a,b):
    A=max(a,b)
    B=min(a,b)
    r=A%B
    sequence=[(A,B,r)]
    while sequence[-1][2]!=0:
        C=sequence[-1]
        sequence=sequence+[(C[1],C[2],C[1]%C[2])]
    return sequence,sequence[-1][1]

# %% [markdown]
# ## Write gcd as linear combination

# %%
def findlinearcombination(A,B):
    #Here is is necessary that A>=B
    sequence=Euclides(A,B)[0]
    N=len(sequence)
    a=[x[0] for x in sequence]
    b=[x[1] for x in sequence]
    q=[a[i]//b[i] for i in range(N)]
    r=[x[2] for x in sequence]
    if N==1:
        return (0,1)
    x=[1,-q[1]]
    y=[-q[0],1+q[0]*q[1]]

    if N==2:
        return (1,-q[0])
    else:
        for i in range(2,N-1):
            newx=x[i-2]-q[i]*x[i-1]
            newy=y[i-2]-y[i-1]*q[i]
            x.append(newx)
            y.append(newy)
        return x[-1],y[-1]

# %%
def extended_gcd(a, b):
    if a == 0:
        return (b, 0, 1)
    else:
        gcd, x1, y1 = extended_gcd(b % a, a)
        # Update x and y using results from recursive call
        x = y1 - (b // a) * x1
        y = x1
        return (gcd, x, y)

# %%
A=98345985534456476876
B=203895402586798798

# %%
findlinearcombination(A,B)
# Out:
# (23550906243882381, -11359437512565845323)

# %%
extended_gcd(A,B)
# Out:
# (2, 23550906243882381, -11359437512565845323)

# %% [markdown]
# ## The two algorithms we wrote for finding linear combinations coincide

# %%
for i in range(1000):
    b=np.random.choice(range(100,1000000))
    epsilon=np.random.choice(range(100,1000))
    a=b+epsilon
    if extended_gcd(a,b)[1:]!=findlinearcombination(a,b):
        print(a,b)
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 for i in range(1000):
# ----> 2     b=np.random.choice(range(100,1000000))
#       3     epsilon=np.random.choice(range(100,1000))
#       4     a=b+epsilon
#
# File numpy/random/mtrand.pyx:1021, in numpy.random.mtrand.RandomState.choice()
#
# File numpy/random/mtrand.pyx:798, in numpy.random.mtrand.RandomState.randint()
#
# File numpy/random/_bounded_integers.pyx:1315, in numpy.random._bounded_integers._rand_int64()
#
# File /opt/miniconda3/envs/topics_alg/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3063, in _prod_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    3049     """
#    3050     Return the minimum of an array or minimum along an axis.
#    3051
#    (...)
#    3057     ndarray.min : equivalent method
#    3058     """
#    3059     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    3060                           keepdims=keepdims, initial=initial, where=where)
# -> 3063 def _prod_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    3064                      initial=None, where=None):
#    3065     return (a, out)
#    3068 @array_function_dispatch(_prod_dispatcher)
#    3069 def prod(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    3070          initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:

# %% [markdown]
# ## RSA

# %% [markdown]
# ### Alice chooses P,Q big prime primes congurent with 2 mod 3

# %%
def isprime(n):
    if n==2:
        True
    else:
        ans=True
        for i in range(2, int(math.sqrt(n)+2)):
            if n%i==0:
                ans=False
                break
        return ans

# %%
def nextprimecongruentto2(n):
    i=0
    while True:
        if isprime(n+i)==True and (n+i)%3==2:
            return n+i
        else:
            i=i+1

# %% [markdown]
# ## fast modular exponentiation

# %%
def modular_exponentiation(a, b, c):
    """
    Compute a^b % c using fast modular exponentiation.

    Args:
        a (int): The base.
        b (int): The exponent.
        c (int): The modulus.

    Returns:
        int: Result of (a^b) % c.
    """
    result = 1  # Initialize result
    a = a % c  # Reduce 'a' modulo 'c' in case it's larger

    while b > 0:
        # If b is odd, multiply 'result' with 'a'
        if b % 2 == 1:
            result = (result * a) % c
        
        # Update 'a' and halve 'b'
        a = (a * a) % c
        b //= 2

    return result

# Example usage:
a = 3
b = 200
c = 13
print(modular_exponentiation(a, b, c))  # Output: 9
# Out:
# 9

# %% [markdown]
# ### Alice finds P and Q and chooses e=3

# %%
X=7935803980
Y=3940085490

# %%
P=nextprimecongruentto2(X)
Q=nextprimecongruentto2(Y)

# %%
Q
# Out:
# 3940085507

# %%
P
# Out:
# 7935804047

# %%
isprime(P)
# Out:
# True

# %%
isprime(Q)
# Out:
# True

# %%
Q%3
# Out:
# 2

# %%
P%3
# Out:
# 2

# %% [markdown]
# ### Alice publishes the folloing information:

# %%
N=P*Q
e=3

# %%
N
# Out:
# 31267746511976646829

# %%
e
# Out:
# 3

# %% [markdown]
# ## Bob chooses a message

# %%
m=113

# %%
math.gcd(m,N)
# Out:
# 1

# %% [markdown]
# ## Bob publishes the encrypted message

# %%
C=(m**3)%N

# %%
C
# Out:
# 1442897

# %% [markdown]
# ## Alice puede encontrar d=e**(-1)

# %%
phi=(P-1)*(Q-1)

# %%
math.gcd(phi,3)
# Out:
# 1

# %%
d=extended_gcd(phi,3)[2]%phi

# %%
d
# Out:
# 20845164333400504851

# %%
(e*d)%phi
# Out:
# 1

# %%
(d*e)%phi
# Out:
# 1

# %%
C
# Out:
# 1442897

# %% [markdown]
# ### Alice raises the encrypted message to the power d to decypher it

# %%
m_Alice=modular_exponentiation(C,d,N)

# %%
m_Alice
# Out:
# 113

# %%
m
# Out:
# 113

# %%
(26**3)*(10**3)
# Out:
# 17576000

# %%
import math
math.factorial(7)
# Out:
# 5040

# %%
ans=0
for i in [6,7,8]:
    ans = ans + 36**i-26**i 
ans
# Out:
# 2684483063360

# %%
math.factorial(52)/(math.factorial(47)*math.factorial(5))
# Out:
# 2598960.0
